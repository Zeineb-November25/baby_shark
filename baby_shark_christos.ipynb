# %%
#Hello team baby shark
#Let's load the file
import pandas as pd

url = "GSAF5.xls"
baby_shark_christos_df = pd.read_excel(url)
display(baby_shark_christos_df)
# Out:
#                 Date    Year        Type             Country  \
# 0       14th October  2025.0  Unprovoked            Columbia
# 1       11th October  2025.0  Unprovoked           Australia
# 2        7th October  2025.0  Unprovoked           Australia
# 3     29th September  2025.0  Unprovoked                 USA
# 4     27th September  2025.0    Provoked          Costa Rica
# ...              ...     ...         ...                 ...
# 7045     Before 1903     0.0  Unprovoked           AUSTRALIA
# 7046     Before 1903     0.0  Unprovoked           AUSTRALIA
# 7047       1900-1905     0.0  Unprovoked                 USA
# 7048       1883-1889     0.0  Unprovoked              PANAMA
# 7049       1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                       State                             Location  \
# 0      Bolivar, del Isolate                    Catagena Province
# 1                Queensland       Cook Esplanade Thursday Island
# 2           South Australia                      Kangaroo Island
# 3            Off California                      Catalina Island
# 4                       NaN                        Cocos Islands
# ...                     ...                                  ...
# 7045      Western Australia                          Roebuck Bay
# 7046      Western Australia                                  NaN
# 7047         North Carolina                       Ocracoke Inlet
# 7048                    NaN                 Panama Bay 8ºN, 79ºW
# 7049       Eastern Province  Below the English fort, Trincomalee
#
#                    Activity                   Name Sex  Age  ...  \
# 0      Swimming with sharks             Male child   M   14  ...
# 1          Fishing/swimming             Samuel Nai   M   14  ...
# 2                   Surfing           Lee Berryman   M  50+  ...
# 3                  Swimming     Christopher Murray   M   54  ...
# 4     Diving-Tagging sharks     Dr. Mauricio Hoyos   M   48  ...
# ...                     ...                    ...  ..  ...  ...
# 7045                 Diving                   male   M  NaN  ...
# 7046           Pearl diving                  Ahmun   M  NaN  ...
# 7047               Swimming  Coast Guard personnel   M  NaN  ...
# 7048                    NaN        Jules Patterson   M  NaN  ...
# 7049               Swimming                   male   M   15  ...
#
#                  Species                                          Source  \
# 0            Nurse shark   Kevin McMurray Trackingsharks.com Andy Currie
# 1     Tiger or Bull shark              Kevin McMurray Trackingsharks.com
# 2          Bronze whaler?              Kevin McMurray Trackingsharks.com
# 3      unknown 1.2m shark  Todd Smith: Kevin McMurray Trackingsharks.com
# 4          Tiger shark 4m  Todd Smith: Kevin McMurray Trackingsharks.com
# ...                   ...                                            ...
# 7045                  NaN               H. Taunton; N. Bartlett,  p. 234
# 7046                  NaN          H. Taunton; N. Bartlett,  pp. 233-234
# 7047                  NaN           F. Schwartz, p.23; C. Creswell, GSAF
# 7048                  NaN                            The Sun, 10/20/1938
# 7049                  NaN                                     S.W. Baker
#
#                                  pdf  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 7045          ND-0005-RoebuckBay.pdf
# 7046               ND-0004-Ahmun.pdf
# 7047  ND-0003-Ocracoke_1900-1905.pdf
# 7048      ND-0002-JulesPatterson.pdf
# 7049              ND-0001-Ceylon.pdf
#
#                                            href formula  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7045  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7046  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7047  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7048  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7049  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2                                                   NaN         NaN
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
# ...                                                 ...         ...
# 7045  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0005
# 7046  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0004
# 7047  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0003
# 7048  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0002
# 7049  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0001
#
#      Case Number.1 original order Unnamed: 21 Unnamed: 22
# 0              NaN            NaN         NaN         NaN
# 1              NaN            NaN         NaN         NaN
# 2              NaN            NaN         NaN         NaN
# 3              NaN            NaN         NaN         NaN
# 4              NaN            NaN         NaN         NaN
# ...            ...            ...         ...         ...
# 7045       ND.0005            6.0         NaN         NaN
# 7046       ND.0004            5.0         NaN         NaN
# 7047       ND.0003            4.0         NaN         NaN
# 7048       ND.0002            3.0         NaN         NaN
# 7049       ND.0001            2.0         NaN         NaN
#
# [7050 rows x 23 columns]

# %%
baby_shark_christos_df.shape
# Out:
# (7050, 23)

# %%
baby_shark_christos_df.dtypes
# Out:
# Date               object
# Year              float64
# Type               object
# Country            object
# State              object
# Location           object
# Activity           object
# Name               object
# Sex                object
# Age                object
# Injury             object
# Fatal Y/N          object
# Time               object
# Species            object
# Source             object
# pdf                object
# href formula       object
# href               object
# Case Number        object
# Case Number.1      object
# original order    float64
# Unnamed: 21        object
# Unnamed: 22        object
# dtype: object

# %%
baby_shark_christos_df.nunique()
# Out:
# Date              6094
# Year               261
# Type                13
# Country            249
# State              939
# Location          4598
# Activity          1608
# Name              5774
# Sex                 10
# Age                251
# Injury            4167
# Fatal Y/N           12
# Time               462
# Species           1729
# Source            5386
# pdf               6789
# href formula      6784
# href              6776
# Case Number       6777
# Case Number.1     6775
# original order    6797
# Unnamed: 21          1
# Unnamed: 22          2
# dtype: int64

# %%
baby_shark_christos_df.describe(include = "all")
# Out:
#           Date         Year        Type Country    State  \
# count   7050.0  7048.000000        7032    7000     6564
# unique  6094.0          NaN          13     249      939
# top     1957.0          NaN  Unprovoked     USA  Florida
# freq       9.0          NaN        5203    2573     1192
# mean       NaN  1935.722900         NaN     NaN      NaN
# std        NaN   271.083776         NaN     NaN      NaN
# min        NaN     0.000000         NaN     NaN      NaN
# 25%        NaN  1948.000000         NaN     NaN      NaN
# 50%        NaN  1986.000000         NaN     NaN      NaN
# 75%        NaN  2010.000000         NaN     NaN      NaN
# max        NaN  2026.000000         NaN     NaN      NaN
#
#                                 Location Activity  Name   Sex     Age  ...  \
# count                               6483     6465  6831  6471  4056.0  ...
# unique                              4598     1608  5774    10   251.0  ...
# top     New Smyrna Beach, Volusia County  Surfing  male     M    16.0  ...
# freq                                 191     1140   679  5654    92.0  ...
# mean                                 NaN      NaN   NaN   NaN     NaN  ...
# std                                  NaN      NaN   NaN   NaN     NaN  ...
# min                                  NaN      NaN   NaN   NaN     NaN  ...
# 25%                                  NaN      NaN   NaN   NaN     NaN  ...
# 50%                                  NaN      NaN   NaN   NaN     NaN  ...
# 75%                                  NaN      NaN   NaN   NaN     NaN  ...
# max                                  NaN      NaN   NaN   NaN     NaN  ...
#
#            Species                            Source  \
# count          3919                             7030
# unique         1729                             5386
# top     White shark  K. McMurray, TrackingSharks.com
# freq            194                              131
# mean            NaN                              NaN
# std             NaN                              NaN
# min             NaN                              NaN
# 25%             NaN                              NaN
# 50%             NaN                              NaN
# 75%             NaN                              NaN
# max             NaN                              NaN
#
#                                       pdf  \
# count                                6799
# unique                               6789
# top     1906.09.27.R.a&b-Munich-Swede.pdf
# freq                                    2
# mean                                  NaN
# std                                   NaN
# min                                   NaN
# 25%                                   NaN
# 50%                                   NaN
# 75%                                   NaN
# max                                   NaN
#
#                                              href formula  \
# count                                                6794
# unique                                               6784
# top     http://sharkattackfile.net/spreadsheets/pdf_di...
# freq                                                    2
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                      href   Case Number  \
# count                                                6796          6798
# unique                                               6776          6777
# top     http://sharkattackfile.net/spreadsheets/pdf_di...  1907.10.16.R
# freq                                                    4             2
# mean                                                  NaN           NaN
# std                                                   NaN           NaN
# min                                                   NaN           NaN
# 25%                                                   NaN           NaN
# 50%                                                   NaN           NaN
# 75%                                                   NaN           NaN
# max                                                   NaN           NaN
#
#        Case Number.1 original order   Unnamed: 21 Unnamed: 22
# count           6797    6799.000000             1           2
# unique          6775            NaN             1           2
# top     1907.10.16.R            NaN  stopped here      Teramo
# freq               2            NaN             1           1
# mean             NaN    3401.152081           NaN         NaN
# std              NaN    1963.076319           NaN         NaN
# min              NaN       2.000000           NaN         NaN
# 25%              NaN    1701.500000           NaN         NaN
# 50%              NaN    3401.000000           NaN         NaN
# 75%              NaN    5100.500000           NaN         NaN
# max              NaN    6802.000000           NaN         NaN
#
# [11 rows x 23 columns]

# %%
# we have 7050 rows
# we have 7050 unique "Date" series, which is a good sign
# year count is smaller than data count, which means that there are two data values missing in series "Year"
# Count is all over the place, there are a lot of data missing in different series
# In series "Country", some value are normal and some capitalized
# In series "Locaion", some values have digits
# Sex appears to have 10 unique values, we need to fix that
# Age seems to have 251 unique values, probably some are negative, some have (+)s, and some might have typos
# Fatal Y/N seems to have 12 unique values, let's reduce to 2 and create 0,1 experssion of Boolean.
# Same for Type. It seems to be a boolean with two values, "Provoked" and "Unprovoked".
# Species also has varying values, some have numbers, others have (OR) in between, I would say here we need some research on how many sharks types could be possible, so that we cast that series according to that
# Activity series has 1608 unique values, I believe we should cluster somehow the values so that we can have actionable insights

# %%
df["Activity"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7050 entries, 0 to 7049
# Series name: Activity
# Non-Null Count  Dtype
# --------------  -----
# 6465 non-null   object
# dtypes: object(1)
# memory usage: 55.2+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            7050 non-null   object
#  1   Year            7048 non-null   float64
#  2   Type            7032 non-null   object
#  3   Country         7000 non-null   object
#  4   State           6564 non-null   object
#  5   Location        6483 non-null   object
#  6   Activity        6465 non-null   object
#  7   Name            6831 non-null   object
#  8   Sex             6471 non-null   object
#  9   Age             4056 non-null   object
#  10  Injury          7015 non-null   object
#  11  Fatal Y/N       6489 non-null   object
#  12  Time            3524 non-null   object
#  13  Species         3919 non-null   object
#  14  Source          7030 non-null   object
#  15  pdf             6799 non-null   object
#  16  href formula    6794 non-null   object
#  17  href            6796 non-null   object
#  18  Case Number     6798 non-null   object
#  19  Case Number.1   6797 non-null   object
#  20  original order  6799 non-null   float64
#  21  Unnamed: 21     1 non-null      object
#  22  Unnamed: 22     2 non-null      object
# dtypes: float64(2), object(21)
# memory usage: 1.2+ MB

# %%
df["Activity"].nunique()
# Out:
# 1608

# %%
df["Activity"].isna().sum()
# Out:
# np.int64(585)

# %%
df["Activity"].head(10)
# Out:
# 0     Swimming with sharks
# 1         Fishing/swimming
# 2                  Surfing
# 3                 Swimming
# 4    Diving-Tagging sharks
# 5                  Surfing
# 6               Snorkeling
# 7                 Swimming
# 8                  Surfing
# 9             Spearfishing
# Name: Activity, dtype: object

# %%
df["Activity"].tail(10)
# Out:
# 7040             NaN
# 7041         Fishing
# 7042         Fishing
# 7043         Fishing
# 7044        Swimming
# 7045          Diving
# 7046    Pearl diving
# 7047        Swimming
# 7048             NaN
# 7049        Swimming
# Name: Activity, dtype: object

# %%
df["Activity"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        Swimming with sharks
# 1            Fishing/swimming
# 2                     Surfing
# 3                    Swimming
# 4       Diving-Tagging sharks
#                 ...
# 7045                   Diving
# 7046             Pearl diving
# 7047                 Swimming
# 7048                      NaN
# 7049                 Swimming
# Name: Activity, Length: 7050, dtype: object>

# %%
df["Activity"].value_counts(dropna=False).head(20)
# Out:
# Activity
# Surfing            1140
# Swimming           1005
# NaN                 585
# Fishing             493
# Spearfishing        391
# Wading              178
# Bathing             164
# Diving              148
# Snorkeling          133
# Standing            113
# Scuba diving         84
# Body boarding        63
# Body surfing         50
# Swimming             47
# Boogie boarding      42
# Kayaking             40
# Free diving          33
# Treading water       33
# Fell overboard       32
# Pearl diving         32
# Name: count, dtype: int64

# %%
# formating the series in a way that it is easier to work with, lowercasing and stripping it from empty spaces
df["Activity"] = df["Activity"].str.strip().str.lower()

# %%
df.head(10)
# Out:
#              Date    Year        Type     Country  \
# 0    14th October  2025.0  Unprovoked    Columbia
# 1    11th October  2025.0  Unprovoked   Australia
# 2     7th October  2025.0  Unprovoked   Australia
# 3  29th September  2025.0  Unprovoked         USA
# 4  27th September  2025.0    Provoked  Costa Rica
# 5   6th September  2025.0  Unprovoked   Australia
# 6   1st September  2025.0  Unprovoked         USA
# 7     30th August  2025.0  Unprovoked         USA
# 8     18th August  2025.0  Unprovoked   Australia
# 9     17th August  2025.0  Unprovoked     Bahamas
#
#                                State                             Location  \
# 0               Bolivar, del Isolate                    Catagena Province
# 1                         Queensland       Cook Esplanade Thursday Island
# 2                    South Australia                      Kangaroo Island
# 3                     Off California                      Catalina Island
# 4                                NaN                        Cocos Islands
# 5                                NSW                     Long Reef Sydney
# 6                            Florida             Horseshoe reef Key Largo
# 7                              Texas                            Galveston
# 8                                NSW                       Cabarita Beach
# 9  Atlantic Ocean near Big Grand Cay  North of Grand Bahama near Freeport
#
#                 Activity                Name Sex  Age  ...  \
# 0   swimming with sharks          Male child   M   14  ...
# 1       fishing/swimming          Samuel Nai   M   14  ...
# 2                surfing        Lee Berryman   M  50+  ...
# 3               swimming  Christopher Murray   M   54  ...
# 4  diving-tagging sharks  Dr. Mauricio Hoyos   M   48  ...
# 5                surfing  Mercury Psillaskis   M   57  ...
# 6             snorkeling     Richard Burrows   M    8  ...
# 7               swimming        Harper Ochoa   F    8  ...
# 8                surfing           Brad Ross   M    ?  ...
# 9           spearfishing          Not stated   M   63  ...
#
#                   Species                                              Source  \
# 0             Nurse shark       Kevin McMurray Trackingsharks.com Andy Currie
# 1      Tiger or Bull shark                  Kevin McMurray Trackingsharks.com
# 2           Bronze whaler?                  Kevin McMurray Trackingsharks.com
# 3       unknown 1.2m shark      Todd Smith: Kevin McMurray Trackingsharks.com
# 4           Tiger shark 4m      Todd Smith: Kevin McMurray Trackingsharks.com
# 5        Great White Shark  Todd Smith: Andy Currie: Simon De Marchi: Kevi...
# 6               Not stated  Todd Smith: US SUN: NY Post: The Guardian: Peo...
# 7               Not stated                           Bob Myatt GSAF : People:
# 8  5m (16.5ft) Great White  Bob Myatt GSAF The Guardian: 9 News: ABS News:...
# 9             Undetermined  Ralph Collier GSAF and Kevin MCMurray Tracking...
#
#    pdf href formula href Case Number Case Number.1 original order Unnamed: 21  \
# 0  NaN          NaN  NaN         NaN           NaN            NaN         NaN
# 1  NaN          NaN  NaN         NaN           NaN            NaN         NaN
# 2  NaN          NaN  NaN         NaN           NaN            NaN         NaN
# 3  NaN          NaN  NaN         NaN           NaN            NaN         NaN
# 4  NaN          NaN  NaN         NaN           NaN            NaN         NaN
# 5  NaN          NaN  NaN         NaN           NaN            NaN         NaN
# 6  NaN          NaN  NaN         NaN           NaN            NaN         NaN
# 7  NaN          NaN  NaN         NaN           NaN            NaN         NaN
# 8  NaN          NaN  NaN         NaN           NaN            NaN         NaN
# 9  NaN          NaN  NaN         NaN           NaN            NaN         NaN
#
#   Unnamed: 22
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
#
# [10 rows x 23 columns]

# %%
# we have 585 NaN values in series "Activity". I decided to assign the value "Unknown" to those, since I don't want to interrupt the dataframe with extreme actions like removing rows.
df["Activity"] = df["Activity"].fillna("unknown")

# %%
df.tail(10)
# Out:
#              Date  Year        Type             Country              State  \
# 7040   Circa 1862   0.0  Unprovoked                 USA             Hawaii
# 7041  Before 1906   0.0  Unprovoked           AUSTRALIA                NaN
# 7042  Before 1906   0.0  Unprovoked           AUSTRALIA                NaN
# 7043  Before 1906   0.0  Unprovoked           AUSTRALIA                NaN
# 7044  Before 1906   0.0  Unprovoked           AUSTRALIA    New South Wales
# 7045  Before 1903   0.0  Unprovoked           AUSTRALIA  Western Australia
# 7046  Before 1903   0.0  Unprovoked           AUSTRALIA  Western Australia
# 7047    1900-1905   0.0  Unprovoked                 USA     North Carolina
# 7048    1883-1889   0.0  Unprovoked              PANAMA                NaN
# 7049    1845-1853   0.0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
#                                  Location      Activity  \
# 7040                                 Puna       unknown
# 7041                                  NaN       fishing
# 7042                                  NaN       fishing
# 7043                                  NaN       fishing
# 7044                                           swimming
# 7045                          Roebuck Bay        diving
# 7046                                  NaN  pearl diving
# 7047                       Ocracoke Inlet      swimming
# 7048                 Panama Bay 8ºN, 79ºW       unknown
# 7049  Below the English fort, Trincomalee      swimming
#
#                        Name Sex  Age  ...  \
# 7040           A "chiefess"   F  NaN  ...
# 7041                    boy   M  NaN  ...
# 7042              fisherman   M  NaN  ...
# 7043              fisherman   M  NaN  ...
# 7044               Arab boy   M  NaN  ...
# 7045                   male   M  NaN  ...
# 7046                  Ahmun   M  NaN  ...
# 7047  Coast Guard personnel   M  NaN  ...
# 7048        Jules Patterson   M  NaN  ...
# 7049                   male   M   15  ...
#
#                                                Species   \
# 7040                                                NaN
# 7041                                       Blue pointer
# 7042                                       Blue pointer
# 7043                                      Blue pointers
# 7044  Said to involve a grey nurse shark that leapt ...
# 7045                                                NaN
# 7046                                                NaN
# 7047                                                NaN
# 7048                                                NaN
# 7049                                                NaN
#
#                                                  Source  \
# 7040                                   Captain W. Young
# 7041  NY Sun, 9/9/1906, referring to account by Loui...
# 7042  NY Sun, 9/9/1906, referring to account by Loui...
# 7043  NY Sun, 9/9/1906, referring to account by Loui...
# 7044  L. Becke in New York Sun, 9/9/1906; L. Schultz...
# 7045                   H. Taunton; N. Bartlett,  p. 234
# 7046              H. Taunton; N. Bartlett,  pp. 233-234
# 7047               F. Schwartz, p.23; C. Creswell, GSAF
# 7048                                The Sun, 10/20/1938
# 7049                                         S.W. Baker
#
#                                     pdf  \
# 7040            ND-0010-Puna Hawaii.pdf
# 7041          ND-0009-boy-Australia.pdf
# 7042   ND-0008-Fisherman2-Australia.pdf
# 7043  ND-0007 - Fisherman-Australia.pdf
# 7044       ND-0006-ArabBoy-Prymount.pdf
# 7045             ND-0005-RoebuckBay.pdf
# 7046                  ND-0004-Ahmun.pdf
# 7047     ND-0003-Ocracoke_1900-1905.pdf
# 7048         ND-0002-JulesPatterson.pdf
# 7049                 ND-0001-Ceylon.pdf
#
#                                            href formula  \
# 7040  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7041  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7042  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7043  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7044  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7045  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7046  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7047  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7048  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7049  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number  \
# 7040  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0010
# 7041  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0009
# 7042  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0008
# 7043  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0007
# 7044  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0006
# 7045  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0005
# 7046  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0004
# 7047  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0003
# 7048  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0002
# 7049  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0001
#
#      Case Number.1 original order Unnamed: 21 Unnamed: 22
# 7040       ND.0010           11.0         NaN         NaN
# 7041       ND.0009           10.0         NaN         NaN
# 7042       ND.0008            9.0         NaN         NaN
# 7043       ND.0007            8.0         NaN         NaN
# 7044       ND.0006            7.0         NaN         NaN
# 7045       ND.0005            6.0         NaN         NaN
# 7046       ND.0004            5.0         NaN         NaN
# 7047       ND.0003            4.0         NaN         NaN
# 7048       ND.0002            3.0         NaN         NaN
# 7049       ND.0001            2.0         NaN         NaN
#
# [10 rows x 23 columns]

# %%
# I intend on clustering the data based on the most frequent values, and by checking with what all-encompassing names I can replace some values.
df["Activity"].value_counts().head(30)
# Out:
# Activity
# surfing            1145
# swimming           1052
# unknown             588
# fishing             509
# spearfishing        399
# wading              178
# bathing             167
# diving              151
# snorkeling          134
# standing            115
# scuba diving        104
# body boarding        70
# boogie boarding      60
# body surfing         55
# kayaking             43
# free diving          35
# treading water       33
# fell overboard       33
# pearl diving         32
# surf skiing          24
# windsurfing          20
# floating             18
# canoeing             17
# walking              17
# shark fishing        16
# kayak fishing        16
# rowing               14
# surf fishing         14
# sea disaster         14
# playing              14
# Name: count, dtype: int64

# %%
# I choose to cluster the values in series "Activity" by

# surfing
# swimming
# fishing (includes spearfhising)
# diving/snorkeling
# boating
# unknown

# All values will be tranformed to the closest relation with these words. 
# Disclaimer: All activities on something bigger than a board will be clustered under boating.
# All water activities like standing, playing, trading water, bathing, etc will go under swimming
# All diving activities will be merged regardless of the nature of diving.
# Snorkeling will be examined differently than swimming, and together with diving, because snorkeling by definition takes place in ecosystems where a lot of fish exist, and therefore, a higher probability of sharks.

# %%
# now I proceed with clustering
# I start with an activity that I want it to be transformed into a category that is later in the sequence of ifs, but contains a word that will be used for surfing categorization, hence, I put that one first.

def map_activity_to_cluster(x: str) -> str:
    x = str(x).lower().strip()
    
    if "fell overboard" in x:
        return "boating"
    if any(word in x for word in ["surf","paddle", "boarding"]):
        return "surfing"
    if any(word in x for word in ["swim", "wading", "bathing", "treading", "standing", "floating", "playing"]):
        return "swimming"
    if "fish" in x:
        return "fishing"
    if any(word in x for word in ["dive", "snorkel", "diving"]):
        return "diving/snorkeling"
    if any(word in x for word in ["boat", "kayak", "canoe", "overboard", "rowing", "sailing"]):
        return "boating"
    if "unknown" in x:
        return "unknown"
    return "other"

# %%
# applying the function to the series

df["Activity_cluster"] = df["Activity"].apply(map_activity_to_cluster)

# %%
df["Activity_cluster"].value_counts()
# Out:
# Activity_cluster
# swimming             1910
# surfing              1644
# fishing              1286
# diving/snorkeling     696
# other                 637
# unknown               589
# boating               288
# Name: count, dtype: int64

# %%
# checking the "other" cluster since it's too big, to see what we might have missed from keywords in our clusters.

df.loc[df["Activity_cluster"] == "other", "Activity"].value_counts().head(40)
# Out:
# Activity
# walking                                                                                                                                         17
# sea disaster                                                                                                                                    14
# fell into the water                                                                                                                              9
# shipwreck                                                                                                                                        7
# murder                                                                                                                                           6
# splashing                                                                                                                                        6
# dangling feet in the water                                                                                                                       5
# feeding sharks                                                                                                                                   5
# tagging sharks                                                                                                                                   4
# paddling                                                                                                                                         4
# watercraft                                                                                                                                       4
# seine netting                                                                                                                                    4
# air disaster                                                                                                                                     4
# jumping                                                                                                                                          4
# jumped into the water                                                                                                                            4
# lifesaving drill                                                                                                                                 4
# clamming                                                                                                                                         4
# shark watching                                                                                                                                   3
# sitting                                                                                                                                          3
# wreck of the schooner pohoiki                                                                                                                    3
# .                                                                                                                                                3
# sculling                                                                                                                                         3
# crabbing                                                                                                                                         3
# suicide                                                                                                                                          3
# sup                                                                                                                                              3
# escaping from alacatraz                                                                                                                          3
# their 9 m launch was run down by a 25,000-ton japanese freighter  on the night of 3-11-1977 & they drifted, clinging to an icebox for 2 days     3
# sitting in shallows                                                                                                                              2
# filming                                                                                                                                          2
# the christie v sank on 11/6/1988, survivors were adrift on a dinghy                                                                              2
# beach seine netting                                                                                                                              2
# washing                                                                                                                                          2
# finning the shark that bit him                                                                                                                   2
#                                                                                                                                                  2
# ocean racing                                                                                                                                     2
# cruising                                                                                                                                         2
# removing shark from net                                                                                                                          2
# collecting shells                                                                                                                                2
# shrimping                                                                                                                                        2
# shark tagging                                                                                                                                    2
# Name: count, dtype: int64
