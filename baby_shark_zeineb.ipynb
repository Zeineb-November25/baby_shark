# %%
import pandas as pd

url = "GSAF5.xls"
df_zeineb = pd.read_excel(url)
display(df_zeineb.head(5))
print("-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-")
print(df_zeineb.columns)
df_zeineb.describe(include = "all")
print("-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-")
# Out:
#              Date    Year        Type     Country                  State  \
# 0    14th October  2025.0  Unprovoked    Columbia   Bolivar, del Isolate
# 1    11th October  2025.0  Unprovoked   Australia             Queensland
# 2     7th October  2025.0  Unprovoked   Australia        South Australia
# 3  29th September  2025.0  Unprovoked         USA         Off California
# 4  27th September  2025.0    Provoked  Costa Rica                    NaN
#
#                          Location               Activity                Name  \
# 0               Catagena Province   Swimming with sharks          Male child
# 1  Cook Esplanade Thursday Island       Fishing/swimming          Samuel Nai
# 2                 Kangaroo Island                Surfing        Lee Berryman
# 3                 Catalina Island               Swimming  Christopher Murray
# 4                   Cocos Islands  Diving-Tagging sharks  Dr. Mauricio Hoyos
#
#   Sex  Age  ...             Species   \
# 0   M   14  ...         Nurse shark
# 1   M   14  ...  Tiger or Bull shark
# 2   M  50+  ...       Bronze whaler?
# 3   M   54  ...   unknown 1.2m shark
# 4   M   48  ...       Tiger shark 4m
#
#                                           Source  pdf href formula href  \
# 0  Kevin McMurray Trackingsharks.com Andy Currie  NaN          NaN  NaN
# 1              Kevin McMurray Trackingsharks.com  NaN          NaN  NaN
# 2              Kevin McMurray Trackingsharks.com  NaN          NaN  NaN
# 3  Todd Smith: Kevin McMurray Trackingsharks.com  NaN          NaN  NaN
# 4  Todd Smith: Kevin McMurray Trackingsharks.com  NaN          NaN  NaN
#
#   Case Number Case Number.1 original order Unnamed: 21 Unnamed: 22
# 0         NaN           NaN            NaN         NaN         NaN
# 1         NaN           NaN            NaN         NaN         NaN
# 2         NaN           NaN            NaN         NaN         NaN
# 3         NaN           NaN            NaN         NaN         NaN
# 4         NaN           NaN            NaN         NaN         NaN
#
# [5 rows x 23 columns]
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Time', 'Species ',
#        'Source', 'pdf', 'href formula', 'href', 'Case Number', 'Case Number.1',
#        'original order', 'Unnamed: 21', 'Unnamed: 22'],
#       dtype='object')
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-

# %%
import pycountry
import re

country_names = [(country.name).lower() for country in pycountry.countries]
country_names = list(map(lambda x:  re.sub('[^a-zA-Z]', '', x.lower().strip()) , country_names ))
#print(country_names)

#print(country_names)
#print(df["Country"].unique())
#print(df["Country"].value_counts())
#print(df["Country"].nunique())
#print("-_-_-_-_-_-_-_-_-_-_-_-_-_-_Print duplicated sum-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-")
#print(df.duplicated(subset=['Country']).sum())


df_zeineb["Country"] = df_zeineb["Country"].fillna("Unkown Country")

df_zeineb['Country'] = df_zeineb['Country'].str.strip()
df_zeineb['Country'] = df_zeineb['Country'].apply(lambda x: re.sub('[^a-zA-Z]', '', x))
df_zeineb['Country'] = df_zeineb['Country'].apply(lambda x: x.lower())

unique_countries = df_zeineb["Country"].unique()
sorted_unique_countries = sorted(unique_countries , reverse = False)

# Display the sorted unique countries
#print(sorted_unique_countries)

def clean_country(country_to_replace, official_list):
    if country_to_replace  == "usa":
        return country_to_replace, False
    else:
        replaced = False
        for official_country in official_list:
        # Check if any part of the official country is in the country_to_replace
            if country_to_replace in official_country:
                replaced = True
                return official_country , replaced  # Return the matched official country name
        # If no match is found, return the original name
        return country_to_replace , replaced


#for country in sorted_unique_countries:
#   print(f"old country: {country} ; then new_country : { clean_country(country, country_names)}")

df_zeineb['Country'] = df_zeineb['Country'].apply(lambda country: clean_country(country, country_names)[0])
#display(df[df['Country'] != "unkowncountry"])
#display(df_zeineb[df_zeineb['Country'] == "usa"])
# Out:
#                     Date    Year        Type Country            State  \
# 3         29th September  2025.0  Unprovoked     usa   Off California
# 6          1st September  2025.0  Unprovoked     usa          Florida
# 7            30th August  2025.0  Unprovoked     usa            Texas
# 10           16th August  2025.0    Provoked     usa          Florida
# 17             19th July  2025.0  Unprovoked     usa          Florida
# ...                  ...     ...         ...     ...              ...
# 6997         Before 1958     0.0  Unprovoked     usa          Florida
# 7031         Before 1921     0.0  Unprovoked     usa          Florida
# 7036  Before 17-Jul-1916     0.0  Unprovoked     usa  North Carolina
# 7040          Circa 1862     0.0  Unprovoked     usa           Hawaii
# 7047           1900-1905     0.0  Unprovoked     usa   North Carolina
#
#                                                Location    Activity  \
# 3                                       Catalina Island    Swimming
# 6                              Horseshoe reef Key Largo  Snorkeling
# 7                                             Galveston    Swimming
# 10                               Cayo Costa Boca Grande     Fishing
# 17    Jupiter Inlet off Jupiter Beach Palm Beach County      Diving
# ...                                                 ...         ...
# 6997                      Palm Beach, Palm Beach County    Standing
# 7031                           Gadsden Point, Tampa Bay     Fishing
# 7036            Somewhere between Hatteras and Beaufort    Swimming
# 7040                                               Puna         NaN
# 7047                                     Ocracoke Inlet    Swimming
#
#                        Name Sex  Age  ...                 Species   \
# 3        Christopher Murray   M   54  ...       unknown 1.2m shark
# 6           Richard Burrows   M    8  ...               Not stated
# 7              Harper Ochoa   F    8  ...               Not stated
# 10              Shawn Meuse   M    ?  ...  Lemon shark 1.8 m (6ft)
# 17                Jeff Joel   M   69  ...              Lemon shark
# ...                     ...  ..  ...  ...                      ...
# 6997           Horton Chase   M  NaN  ...                      NaN
# 7031           James Kelley   M  NaN  ...                      NaN
# 7036        "youthful male"   M  NaN  ...                      NaN
# 7040           A "chiefess"   F  NaN  ...                      NaN
# 7047  Coast Guard personnel   M  NaN  ...                      NaN
#
#                                                  Source  \
# 3         Todd Smith: Kevin McMurray Trackingsharks.com
# 6     Todd Smith: US SUN: NY Post: The Guardian: Peo...
# 7                              Bob Myatt GSAF : People:
# 10    Johannes Marchand: Kevin McMurray Trackingshar...
# 17    Brandyn Gartelman: Kevin McMurray Trackingshar...
# ...                                                 ...
# 6997         V.M. Coppleson (1956), p.255;  R.F. Hutton
# 7031                                     T. Helm, p.219
# 7036     C. Creswell, GSAF; Wilmington Star, 7/17/1916
# 7040                                   Captain W. Young
# 7047               F. Schwartz, p.23; C. Creswell, GSAF
#
#                                     pdf  \
# 3                                   NaN
# 6                                   NaN
# 7                                   NaN
# 10                                  NaN
# 17                                  NaN
# ...                                 ...
# 6997            ND-0056-HortonChase.pdf
# 7031                 ND-0019-Kelley.pdf
# 7036  ND-0014-pre1916-NorthCarolina.pdf
# 7040            ND-0010-Puna Hawaii.pdf
# 7047     ND-0003-Ocracoke_1900-1905.pdf
#
#                                            href formula  \
# 3                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 10                                                  NaN
# 17                                                  NaN
# ...                                                 ...
# 6997  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7031  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7036  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7040  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7047  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number  \
# 3                                                   NaN         NaN
# 6                                                   NaN         NaN
# 7                                                   NaN         NaN
# 10                                                  NaN         NaN
# 17                                                  NaN         NaN
# ...                                                 ...         ...
# 6997  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0056
# 7031  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0019
# 7036  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0014
# 7040  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0010
# 7047  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0003
#
#      Case Number.1 original order Unnamed: 21 Unnamed: 22
# 3              NaN            NaN         NaN         NaN
# 6              NaN            NaN         NaN         NaN
# 7              NaN            NaN         NaN         NaN
# 10             NaN            NaN         NaN         NaN
# 17             NaN            NaN         NaN         NaN
# ...            ...            ...         ...         ...
# 6997       ND.0056           54.0         NaN         NaN
# 7031       ND.0019           20.0         NaN         NaN
# 7036       ND.0014           15.0         NaN         NaN
# 7040       ND.0010           11.0         NaN         NaN
# 7047       ND.0003            4.0         NaN         NaN
#
# [2573 rows x 23 columns]
