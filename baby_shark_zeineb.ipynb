# %%
#Hello team baby shark
#Let's load the file
import pandas as pd

url = "GSAF5.xls"
df = pd.read_excel(url)
display(df.head(10))
print("-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-")
print(df.columns)
df.describe(include = "all")
print("-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-")
relevent_columns_To_clean = ['Date', 'Year', 'Type', 'Country', 'State', 'Activity',
       'Name', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Time', 'Species ']
relevent_columns_To_analyze = ['Type', 'Country', 'State', 'Activity', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Species ']
for data in relevent_columns_To_analyze :
    print(f" data for :  {data}")
    print(df[data].unique())
    print("-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-")
    print("-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-")
    print(f" Values count for :  {data}")
    print(df[data].value_counts())
    print("-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-")
# Out:
#              Date    Year        Type     Country  \
# 0    14th October  2025.0  Unprovoked    Columbia
# 1    11th October  2025.0  Unprovoked   Australia
# 2     7th October  2025.0  Unprovoked   Australia
# 3  29th September  2025.0  Unprovoked         USA
# 4  27th September  2025.0    Provoked  Costa Rica
# 5   6th September  2025.0  Unprovoked   Australia
# 6   1st September  2025.0  Unprovoked         USA
# 7     30th August  2025.0  Unprovoked         USA
# 8     18th August  2025.0  Unprovoked   Australia
# 9     17th August  2025.0  Unprovoked     Bahamas
#
#                                State                             Location  \
# 0               Bolivar, del Isolate                    Catagena Province
# 1                         Queensland       Cook Esplanade Thursday Island
# 2                    South Australia                      Kangaroo Island
# 3                     Off California                      Catalina Island
# ...
