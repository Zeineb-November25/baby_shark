# %%
import pandas as pd
import numpy as np

url = "GSAF5.xls"
df = pd.read_excel(url)
zina_df = df.copy()
display(zina_df)
# Out:
#                 Date    Year        Type             Country  \
# 0       14th October  2025.0  Unprovoked            Columbia
# 1       11th October  2025.0  Unprovoked           Australia
# 2        7th October  2025.0  Unprovoked           Australia
# 3     29th September  2025.0  Unprovoked                 USA
# 4     27th September  2025.0    Provoked          Costa Rica
# ...              ...     ...         ...                 ...
# 7045     Before 1903     0.0  Unprovoked           AUSTRALIA
# 7046     Before 1903     0.0  Unprovoked           AUSTRALIA
# 7047       1900-1905     0.0  Unprovoked                 USA
# 7048       1883-1889     0.0  Unprovoked              PANAMA
# 7049       1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                       State                             Location  \
# 0      Bolivar, del Isolate                    Catagena Province
# 1                Queensland       Cook Esplanade Thursday Island
# 2           South Australia                      Kangaroo Island
# 3            Off California                      Catalina Island
# 4                       NaN                        Cocos Islands
# ...                     ...                                  ...
# 7045      Western Australia                          Roebuck Bay
# 7046      Western Australia                                  NaN
# 7047         North Carolina                       Ocracoke Inlet
# 7048                    NaN                 Panama Bay 8ºN, 79ºW
# 7049       Eastern Province  Below the English fort, Trincomalee
#
#                    Activity                   Name Sex  Age  ...  \
# 0      Swimming with sharks             Male child   M   14  ...
# 1          Fishing/swimming             Samuel Nai   M   14  ...
# 2                   Surfing           Lee Berryman   M  50+  ...
# 3                  Swimming     Christopher Murray   M   54  ...
# 4     Diving-Tagging sharks     Dr. Mauricio Hoyos   M   48  ...
# ...                     ...                    ...  ..  ...  ...
# 7045                 Diving                   male   M  NaN  ...
# 7046           Pearl diving                  Ahmun   M  NaN  ...
# 7047               Swimming  Coast Guard personnel   M  NaN  ...
# 7048                    NaN        Jules Patterson   M  NaN  ...
# 7049               Swimming                   male   M   15  ...
#
#                  Species                                          Source  \
# 0            Nurse shark   Kevin McMurray Trackingsharks.com Andy Currie
# 1     Tiger or Bull shark              Kevin McMurray Trackingsharks.com
# 2          Bronze whaler?              Kevin McMurray Trackingsharks.com
# 3      unknown 1.2m shark  Todd Smith: Kevin McMurray Trackingsharks.com
# 4          Tiger shark 4m  Todd Smith: Kevin McMurray Trackingsharks.com
# ...                   ...                                            ...
# 7045                  NaN               H. Taunton; N. Bartlett,  p. 234
# 7046                  NaN          H. Taunton; N. Bartlett,  pp. 233-234
# 7047                  NaN           F. Schwartz, p.23; C. Creswell, GSAF
# 7048                  NaN                            The Sun, 10/20/1938
# 7049                  NaN                                     S.W. Baker
#
#                                  pdf  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 7045          ND-0005-RoebuckBay.pdf
# 7046               ND-0004-Ahmun.pdf
# 7047  ND-0003-Ocracoke_1900-1905.pdf
# 7048      ND-0002-JulesPatterson.pdf
# 7049              ND-0001-Ceylon.pdf
#
#                                            href formula  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7045  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7046  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7047  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7048  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7049  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2                                                   NaN         NaN
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
# ...                                                 ...         ...
# 7045  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0005
# 7046  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0004
# 7047  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0003
# 7048  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0002
# 7049  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0001
#
#      Case Number.1 original order Unnamed: 21 Unnamed: 22
# 0              NaN            NaN         NaN         NaN
# 1              NaN            NaN         NaN         NaN
# 2              NaN            NaN         NaN         NaN
# 3              NaN            NaN         NaN         NaN
# 4              NaN            NaN         NaN         NaN
# ...            ...            ...         ...         ...
# 7045       ND.0005            6.0         NaN         NaN
# 7046       ND.0004            5.0         NaN         NaN
# 7047       ND.0003            4.0         NaN         NaN
# 7048       ND.0002            3.0         NaN         NaN
# 7049       ND.0001            2.0         NaN         NaN
#
# [7050 rows x 23 columns]

# %%
zina_df.shape

# %%
zina_df.describe(include="all")

# %%
zina_df.info()

# %%
zina_df.nunique()

# %%
zina_df.dtypes

# %%
zina_df.head(20)

# %%
zina_df.tail(20)

# %%
(zina_df.isna().mean().sort_values(ascending=False) * 100).round(2)

# %%
zina_df.duplicated().sum()

# %%
zina_df.columns

# %%
zina_df.isnull()

# %%
zina_df['Age'].value_counts()

# %%
zina_df.isna().sum() # Age : 2994 NA values

# %%
zina_df.drop_duplicates

# %%
zina_df.dropna(axis=1)

# %%
zina_df.shape

# %%
zina_df['Age'].min()

# %%
zina_df['Age'].max()

# %%
word_map = {"teen": 15,"teens": 15,"young": 18,"adult": 30,"(adult)": 30,"elderly": 75,"middle age": 45,"middle-age": 45}

def extract_age(value):
    if pd.isna(value): # check if the value is missing
        return np.nan # if true : returns a missing value NaN

    value = str(value).strip().lower() #coverts to string, removes whitespace, converts to lowercase 

    for key, age in word_map.items(): #using the word_map to inter values
        if key in value:
            return age

    clean_value = value.replace("+", " ").replace("&", " ").replace("-", " ").replace(",", " ") # to remove +, &, -, -> spaces

    parts = clean_value.split() # .split() on spaces and get all the numbers
    
    numbers = []
    for part in parts:
        if part.isdigit():        # check if it is a number
            numbers.append(int(part))
            
    if numbers: #If we found numbers, return the average; example :("28 & 22", "50+", "16 to 18")
        return round(sum(numbers) / len(numbers))

    return np.nan #If nothing found, return NaN

zina_df.insert(zina_df.columns.get_loc("Age") + 1,"Age_clean",zina_df["Age"].apply(extract_age))

zina_df[["Age", "Age_clean"]].head()
# Out:
#    Age  Age_clean
# 0   14       14.0
# 1   14       14.0
# 2  50+       50.0
# 3   54       54.0
# 4   48       48.0

# %%
zina_df.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Age_clean', 'Injury', 'Fatal Y/N', 'Time',
#        'Species ', 'Source', 'pdf', 'href formula', 'href', 'Case Number',
#        'Case Number.1', 'original order', 'Unnamed: 21', 'Unnamed: 22'],
#       dtype='object')

# %%
pd.set_option("display.max_columns", None) # to see hidden columns

# %%
zina_df.head()
# Out:
#              Date    Year        Type     Country                  State  \
# 0    14th October  2025.0  Unprovoked    Columbia   Bolivar, del Isolate
# 1    11th October  2025.0  Unprovoked   Australia             Queensland
# 2     7th October  2025.0  Unprovoked   Australia        South Australia
# 3  29th September  2025.0  Unprovoked         USA         Off California
# 4  27th September  2025.0    Provoked  Costa Rica                    NaN
#
#                          Location               Activity                Name  \
# 0               Catagena Province   Swimming with sharks          Male child
# 1  Cook Esplanade Thursday Island       Fishing/swimming          Samuel Nai
# 2                 Kangaroo Island                Surfing        Lee Berryman
# 3                 Catalina Island               Swimming  Christopher Murray
# 4                   Cocos Islands  Diving-Tagging sharks  Dr. Mauricio Hoyos
#
#   Sex  Age  Age_clean                       Injury Fatal Y/N        Time  \
# 0   M   14       14.0           Severe hand injury         N  Not stated
# 1   M   14       14.0  Serious abdonminal injuries         N    1823 hrs
# 2   M  50+       50.0         Lacerations to calf          N     1330hrs
# 3   M   54       54.0          Leg and foot injury         N     0100hrs
# 4   M   48       48.0           Head face and arms         N  Not stated
#
#               Species                                          Source  pdf  \
# 0         Nurse shark   Kevin McMurray Trackingsharks.com Andy Currie  NaN
# 1  Tiger or Bull shark              Kevin McMurray Trackingsharks.com  NaN
# 2       Bronze whaler?              Kevin McMurray Trackingsharks.com  NaN
# 3   unknown 1.2m shark  Todd Smith: Kevin McMurray Trackingsharks.com  NaN
# 4       Tiger shark 4m  Todd Smith: Kevin McMurray Trackingsharks.com  NaN
#
#   href formula href Case Number Case Number.1  original order Unnamed: 21  \
# 0          NaN  NaN         NaN           NaN             NaN         NaN
# 1          NaN  NaN         NaN           NaN             NaN         NaN
# 2          NaN  NaN         NaN           NaN             NaN         NaN
# 3          NaN  NaN         NaN           NaN             NaN         NaN
# 4          NaN  NaN         NaN           NaN             NaN         NaN
#
#   Unnamed: 22
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
